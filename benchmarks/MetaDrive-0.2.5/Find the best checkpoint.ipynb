# %%
import os
import time

import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import re

from copo import pretty_print

# %matplotlib inline

# %%
EVALUATE_RESULTS_PATH = "./formal_evaluate_results"

os.listdir(EVALUATE_RESULTS_PATH)
# Out:
# ['.DS_Store',
#  '1011_ccppo_concat_evaluate_results.csv',
#  '1003_copo_formal_evaluate_results.csv',
#  '1003_ippo_evaluate_results.csv',
#  '1003_cl_evaluate_results.csv',
#  '1012_ccppo_mf_evaluate_results.csv']

# %%
eval_df = []

algo_set = set()
env_set = set()

count = 0

for p in os.listdir(EVALUATE_RESULTS_PATH):
    match = re.search("(.*?)_evaluate_results.csv", p)
    
    if match:
        
        count += 1
        
        exp_name = match[1]
        
        full_p = os.path.abspath(os.path.join(EVALUATE_RESULTS_PATH, p))
        
        try:
            tmp = pd.read_csv(full_p)
        except Exception as e:
            print(full_p)
            raise e

        tmp["exp_name"] = exp_name
        tmp["model_index"] = p
        
        if "_cl" in exp_name:
            # Special trement for CL, removing the evaluate results of the wrong checkpoints
            # We only keep results for checkpoint-1250
            # This might be inaccurate if you have multiple checkpoints after 3rd stage.
            tmp = tmp[tmp['path'].str.contains('1250')]
        
        eval_df.append(tmp)
        
        print(f"[{count}] Processed the agent: ", exp_name)
    else:
        print(p, " not exists!")
                
eval_df = pd.concat(eval_df)
# Out:
# .DS_Store  not exists!
# [1] Processed the agent:  1011_ccppo_concat
# [2] Processed the agent:  1003_copo_formal
# [3] Processed the agent:  1003_ippo
# [4] Processed the agent:  1003_cl
# [5] Processed the agent:  1012_ccppo_mf

# %%
for env_short_name in ["Inter", "Round", "Parking", "Bottle", "Tollgate"]:
    eval_df.loc[
        [env_short_name in item for item in eval_df.env],
        "env"
    ] = env_short_name
    
eval_df.loc[
    ["MetaDrive" in item for item in eval_df.env],
    "env"
] = "PGMap"

# %% [markdown]
# ## Find the best checkpoint for each env and algo.
#
# That is applying maximum operation across all seeds and checkpoints for a given env and algo.

# %%
for env, gb_env in eval_df.groupby("env"):  # Each env
    for exp_name, gb in gb_env.groupby('exp_name'):  # Each algorithm
        
        best_checkpoint_value = float("-inf")
        best_checkpoint_data = None
        best_checkpoint_path = None
        
        for seed, seed_gb in gb.groupby("seed"):  # Each seed
            
            for path, ckpt_gb in seed_gb.groupby("path"):  # Find the best checkpoint
                
                val = ckpt_gb["success_rate"].mean()
                assert np.isscalar(val)
                
                if val > best_checkpoint_value:
                    best_checkpoint_value = val
                    best_checkpoint_data = ckpt_gb    
                    best_checkpoint_path = path
            
        print(f"For env={env}, algo={exp_name}, seed={seed}, we find {len(seed_gb.path.unique())} checkpoints and the best success rate is {best_checkpoint_value:.3f}")
        print(f"Path:\n{best_checkpoint_path}\n\n")
# Out:
# For env=Bottle, algo=1003_cl, seed=12000, we find 1 checkpoints and the best success rate is 0.738
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_cl/IPPOCL_CLMultiAgentBottleneckEnv_e2a67_00039_39_env=CLMultiAgentBottleneckEnv,start_seed=11000,seed=0_2022-10-04_03-46-40/checkpoint_1250/checkpoint-1250
#
#
# For env=Bottle, algo=1003_copo_formal, seed=12000, we find 6 checkpoints and the best success rate is 0.781
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentBottleneckEnv_647d3_00003_3_env=CCMultiAgentBottleneckEnv,start_seed=5000,seed=0,use_centralized_critic=False,use_2022-10-04_10-43-57/checkpoint_620/checkpoint-620
#
#
# For env=Bottle, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.610
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentBottleneckEnv_ad347_00045_45_env=MultiAgentBottleneckEnv,start_seed=12000,seed=0_2022-10-04_01-25-13/checkpoint_530/checkpoint-530
#
#
# For env=Bottle, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.547
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentBottleneckEnv_8533d_00038_38_counterfactual=True,env=CCMultiAgentBottleneckEnv,start_s_2022-10-11_17-56-49/checkpoint_625/checkpoint-625
#
#
# For env=Bottle, algo=1012_ccppo_mf, seed=12000, we find 4 checkpoints and the best success rate is 0.463
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentBottleneckEnv_2700f_00038_38_counterfactual=True,env=CCMultiAgentBottleneckEnv,start_s_2022-10-12_19-47-20/checkpoint_620/checkpoint-620
#
#
# For env=Inter, algo=1003_cl, seed=12000, we find 1 checkpoints and the best success rate is 0.804
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_cl/IPPOCL_CLMultiAgentIntersectionEnv_e2a67_00043_43_env=CLMultiAgentIntersectionEnv,start_seed=12000,seed=0_2022-10-04_04-16-32/checkpoint_1250/checkpoint-1250
#
#
# For env=Inter, algo=1003_copo_formal, seed=12000, we find 6 checkpoints and the best success rate is 0.861
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentIntersectionEnv_647d3_00010_10_env=CCMultiAgentIntersectionEnv,start_seed=6000,seed=0,use_centralized_critic=Fals_2022-10-04_10-43-57/checkpoint_570/checkpoint-570
#
#
# For env=Inter, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.795
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentIntersectionEnv_ad347_00037_37_env=MultiAgentIntersectionEnv,start_seed=11000,seed=0_2022-10-04_00-33-01/checkpoint_370/checkpoint-370
#
#
# For env=Inter, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.807
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentIntersectionEnv_8533d_00023_23_counterfactual=True,env=CCMultiAgentIntersectionEnv,sta_2022-10-11_13-10-14/checkpoint_480/checkpoint-480
#
#
# For env=Inter, algo=1012_ccppo_mf, seed=12000, we find 4 checkpoints and the best success rate is 0.794
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentIntersectionEnv_2700f_00047_47_counterfactual=True,env=CCMultiAgentIntersectionEnv,sta_2022-10-12_21-48-32/checkpoint_520/checkpoint-520
#
#
# For env=PGMap, algo=1003_cl, seed=12000, we find 1 checkpoints and the best success rate is 0.042
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_cl/IPPOCL_CLMultiAgentMetaDrive_e2a67_00023_23_env=CLMultiAgentMetaDrive,start_seed=8000,seed=0_2022-10-03_22-29-52/checkpoint_1250/checkpoint-1250
#
#
# For env=PGMap, algo=1003_copo_formal, seed=12000, we find 5 checkpoints and the best success rate is 0.626
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentMetaDrive_647d3_00035_35_env=CCMultiAgentMetaDrive,start_seed=10000,seed=0,use_centralized_critic=False,use_distr_2022-10-05_07-45-18/checkpoint_470/checkpoint-470
#
#
# For env=PGMap, algo=1003_ippo, seed=12000, we find 3 checkpoints and the best success rate is 0.541
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentMetaDrive_ad347_00035_35_env=MultiAgentMetaDrive,start_seed=10000,seed=0_2022-10-04_00-27-50/checkpoint_510/checkpoint-510
#
#
# For env=PGMap, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.317
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentMetaDrive_8533d_00033_33_counterfactual=True,env=CCMultiAgentMetaDrive,start_seed=1000_2022-10-11_15-56-10/checkpoint_480/checkpoint-480
#
#
# For env=PGMap, algo=1012_ccppo_mf, seed=12000, we find 3 checkpoints and the best success rate is 0.098
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentMetaDrive_2700f_00033_33_counterfactual=True,env=CCMultiAgentMetaDrive,start_seed=1000_2022-10-12_18-12-30/checkpoint_620/checkpoint-620
#
#
# For env=Parking, algo=1003_cl, seed=12000, we find 1 checkpoints and the best success rate is 0.236
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_cl/IPPOCL_CLMultiAgentParkingLotEnv_e2a67_00012_12_env=CLMultiAgentParkingLotEnv,start_seed=7000,seed=0_2022-10-03_19-40-19/checkpoint_1250/checkpoint-1250
#
#
# For env=Parking, algo=1003_copo_formal, seed=12000, we find 5 checkpoints and the best success rate is 0.282
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentParkingLotEnv_647d3_00012_12_env=CCMultiAgentParkingLotEnv,start_seed=7000,seed=0,use_centralized_critic=False,us_2022-10-04_10-43-57/checkpoint_625/checkpoint-625
#
#
# For env=Parking, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.272
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentParkingLotEnv_ad347_00018_18_env=MultiAgentParkingLotEnv,start_seed=8000,seed=0_2022-10-03_19-38-49/checkpoint_510/checkpoint-510
#
#
# For env=Parking, algo=1011_ccppo_concat, seed=12000, we find 4 checkpoints and the best success rate is 0.252
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentParkingLotEnv_8533d_00042_42_counterfactual=True,env=CCMultiAgentParkingLotEnv,start_s_2022-10-11_18-43-10/checkpoint_530/checkpoint-530
#
#
# For env=Parking, algo=1012_ccppo_mf, seed=12000, we find 4 checkpoints and the best success rate is 0.294
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentParkingLotEnv_2700f_00042_42_counterfactual=True,env=CCMultiAgentParkingLotEnv,start_s_2022-10-12_21-07-23/checkpoint_625/checkpoint-625
#
#
# For env=Round, algo=1003_cl, seed=12000, we find 1 checkpoints and the best success rate is 0.783
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_cl/IPPOCL_CLMultiAgentRoundaboutEnv_e2a67_00046_46_env=CLMultiAgentRoundaboutEnv,start_seed=12000,seed=0_2022-10-04_05-42-28/checkpoint_1250/checkpoint-1250
#
#
# For env=Round, algo=1003_copo_formal, seed=12000, we find 5 checkpoints and the best success rate is 0.860
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentRoundaboutEnv_647d3_00001_1_env=CCMultiAgentRoundaboutEnv,start_seed=5000,seed=0,use_centralized_critic=False,use_2022-10-04_10-43-57/checkpoint_625/checkpoint-625
#
#
# For env=Round, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.770
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentRoundaboutEnv_ad347_00040_40_env=MultiAgentRoundaboutEnv,start_seed=11000,seed=0_2022-10-04_00-55-49/checkpoint_360/checkpoint-360
#
#
# For env=Round, algo=1011_ccppo_concat, seed=12000, we find 3 checkpoints and the best success rate is 0.753
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentRoundaboutEnv_8533d_00043_43_counterfactual=True,env=CCMultiAgentRoundaboutEnv,start_s_2022-10-11_18-55-17/checkpoint_610/checkpoint-610
#
#
# For env=Round, algo=1012_ccppo_mf, seed=12000, we find 3 checkpoints and the best success rate is 0.834
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentRoundaboutEnv_2700f_00031_31_counterfactual=True,env=CCMultiAgentRoundaboutEnv,start_s_2022-10-12_17-20-43/checkpoint_340/checkpoint-340
#
#
# For env=Tollgate, algo=1003_cl, seed=12000, we find 1 checkpoints and the best success rate is 0.820
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_cl/IPPOCL_CLMultiAgentTollgateEnv_e2a67_00014_14_env=CLMultiAgentTollgateEnv,start_seed=7000,seed=0_2022-10-03_19-40-19/checkpoint_1250/checkpoint-1250
#
#
# For env=Tollgate, algo=1003_copo_formal, seed=12000, we find 6 checkpoints and the best success rate is 0.641
# Path:
# /home/zhpeng/CoPO/copo_code/copo/1003_copo/CoPO_CCMultiAgentTollgateEnv_647d3_00014_14_env=CCMultiAgentTollgateEnv,start_seed=7000,seed=0,use_centralized_critic=False,use_di_2022-10-04_10-43-57/checkpoint_625/checkpoint-625
#
#
# For env=Tollgate, algo=1003_ippo, seed=12000, we find 4 checkpoints and the best success rate is 0.095
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1003_ippo/IPPO_MultiAgentTollgateEnv_ad347_00008_8_env=MultiAgentTollgateEnv,start_seed=6000,seed=0_2022-10-03_19-38-49/checkpoint_610/checkpoint-610
#
#
# For env=Tollgate, algo=1011_ccppo_concat, seed=12000, we find 3 checkpoints and the best success rate is 0.111
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1011_ccppo_concat/CCPPOTrainerForMAOurEnvironment_CCMultiAgentTollgateEnv_8533d_00004_4_counterfactual=True,env=CCMultiAgentTollgateEnv,start_seed=5_2022-10-11_10-52-49/checkpoint_625/checkpoint-625
# For env=Tollgate, algo=1012_ccppo_mf, seed=12000, we find 3 checkpoints and the best success rate is 0.490
# Path:
# /home/zhenghao/CoPO/copo_code/copo/1012_ccppo_mf/CCPPOTrainerForMAOurEnvironment_CCMultiAgentTollgateEnv_2700f_00028_28_counterfactual=True,env=CCMultiAgentTollgateEnv,start_seed=_2022-10-12_17-08-30/checkpoint_625/checkpoint-625
